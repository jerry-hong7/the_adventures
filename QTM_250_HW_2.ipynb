# %% [markdown]
# <a href="https://colab.research.google.com/github/jerry-hong7/the_adventures/blob/main/QTM_250_HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploring the Trends between Popular NBA Players and Names in the United States**
#
# ### Faiz Daredia, Conor Harty, Catherine Haus, Jerry Hong, and Lenora Upchurch

# %% [markdown]
# <img src="https://www.logodesignlove.com/images/classic/nba-logo.jpg">

# %% [markdown]
# ## Introduction & Hypothesis

# %% [markdown]
# In this project, we will look at six well-known basketball players---Kobe Bryant, Stephen Curry, Larry Bird, Kevin Garnett, Michael Jordan, and Dwyane Wade---who have won championships over the past few decades. We want to see whether their was a positive association between the prevalence of their first names and their winning of a championship or success in a season. Our hypothesis is that after these players won a championship or experienced a breakout season, their names increased in usage/popularity. When a player has a successful year or wins the championship, their popularity will increase, which may affect the name they choose for their child if they admire a particular player. Thus, we expect their names to also grow in popularity.
#
# This hypothesis is not unfounded. For instance, research from Childcare.co.uk showed a 112% increase in the number of children named after celebrities and film/tv characters between 2009 to 2019. Names such as Ariana, the name of the top-selling female pop star Ariana Grande, and Jesse, a character from the immensely popular show Breaking Bad, were two of the most popular. Richard Conway, the founder of Childrecare.co.UK commented on the trend as well, claiming that '"celebrities have a huge influence on our culture"' and that '"people have historically named their children after their icons."

# %% [markdown]
# ## Methodology

# %% [markdown]
# Link to queries:
#
# https://console.cloud.google.com/bigquery?sq=648957950646:7ebaa9dff4f2429c8ee4b818b450618a
#
# Link to tables:
#
# https://github.com/jerry-hong7/nbaSQL

# %% [markdown]
# To begin, the public dataset USA Names will be loaded into BigQuery. Accessing the data will allow investigation into the hypothesis that the popularity of famous NBA player’s names will increase after either having a breakout year or the year their team won the championship. We define "breakout year" in which a player had a significantly successful season relative to their prior seasons. This is primarily attributed to their increase in overall statistics (i.e. points per game, rebounds per game, assists per game, etc.) In order to account for fluctuations in birth rate, individual tables will include the year each player is drafted to 2021. We explored six famous NBA players from different eras and see possible trends in the popularity of their name throughout their career. We used a series of SQL queries to create a table logging the number of occurences of a name per year. Because these players are drafted at differnt years, some tables will have more rows than others.

# %%
# import necessary packages
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Kobe Bryant

# %% [markdown]
# ![gettyimages-490703338.jpg](data:image/jpeg;base64,...)

# %%
# import each SQL result table
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/1Ee1YcjDMhy4MAn5cv3pparGwzQqzFBZY0dTPOWBiDUI/edit?usp=sharing')
sheet = sp.worksheet('Sheet1')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0   year  name   n
# 1   2021  Kobe  44
# 2   2020  Kobe  42
# 3   2019  Kobe  32
# 4   2018  Kobe  29
# 5   2017  Kobe  36
# 6   2016  Kobe  34
# 7   2015  Kobe  29
# 8   2014  Kobe  33
# 9   2013  Kobe  35
# 10  2012  Kobe  38
# 11  2011  Kobe  34
# 12  2010  Kobe  38
# 13  2009  Kobe  38
# 14  2008  Kobe  39
# 15  2007  Kobe  33
# 16  2006  Kobe  33
# 17  2005  Kobe  34
# 18  2004  Kobe  37
# 19  2003  Kobe  46
# 20  2002  Kobe  47
# 21  2001  Kobe  47
# 22  2000  Kobe  46
# 23  1999  Kobe  40
# 24  1998  Kobe  45
# 25  1997  Kobe  29

# %% [markdown]
# ![n vs. year for Kobe Bryant.png](data:image/png;base64,...)

# %% [markdown]
# Since Kobe was drafted, his popularity rapidly grew, which can attribute to the steep rise in his name. His name peaked when his team won three consecutive championships from 2000 to 2002. There is a slight drop in 2003-2005 since his star teammate Shaquille O'Neal left the team, causing a drop in overall team performance. While the team did not win a championship in the late 2000's, Kobe's individual performance increased immsensely, culminated with an MVP award in 2008. Thus, his popularity stock grew back, which may correlate with rise in his name.

# %% [markdown]
# ## Larry Bird

# %% [markdown]
# ![Bird_Larry_USATSI_5474012.jpg](data:image/jpeg;base64,...)

# %%
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/1xRlXEODjnbk5KLPMTpu2eNYHWmnE-y6ojeR44OkQPLo/edit?usp=sharing')
sheet = sp.worksheet('Sheet1')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0   year   name   n
# 1   2021  Larry  19
# 2   2020  Larry  23
# 3   2019  Larry  22
# 4   2018  Larry  24
# 5   2017  Larry  29
# 6   2016  Larry  29
# 7   2015  Larry  28
# 8   2014  Larry  29
# 9   2013  Larry  30
# 10  2012  Larry  34
# 11  2011  Larry  34
# 12  2010  Larry  34
# 13  2009  Larry  34
# 14  2008  Larry  33
# 15  2007  Larry  36
# 16  2006  Larry  32
# 17  2005  Larry  32
# 18  2004  Larry  31
# 19  2003  Larry  36
# 20  2002  Larry  34
# 21  2001  Larry  33
# 22  2000  Larry  34
# 23  1999  Larry  36
# 24  1998  Larry  39
# 25  1997  Larry  35
# 26  1996  Larry  39
# 27  1995  Larry  39
# 28  1994  Larry  39
# 29  1993  Larry  41
# 30  1992  Larry  42
# 31  1991  Larry  41
# 32  1990  Larry  43
# 33  1989  Larry  43
# 34  1988  Larry  46
# 35  1987  Larry  43
# 36  1986  Larry  42
# 37  1985  Larry  47
# 38  1984  Larry  45
# 39  1983  Larry  48
# 40  1982  Larry  49
# 41  1981  Larry  46
# 42  1980  Larry  53
# 43  1979  Larry  46
# 44  1978  Larry  50

# %% [markdown]
# ![n vs. year for Larry Bird .png](data:image/png;base64,...)

# %% [markdown]
# ## Stephen Curry

# %% [markdown]
# ![Steph-Curry-LookingUp-Mavericks-USATSI-19926783.jpg](data:image/jpeg;base64,...)

# %%
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/1ONLloG1qFnhsxSXm5mtdEBJ2XBw6Ub2B0A4fAsCeapw/edit?usp=sharing')
sheet = sp.worksheet('Sheet1')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0   year     name   n
# 1   2021  Stephen  38
# 2   2020  Stephen  37
# 3   2019  Stephen  39
# 4   2018  Stephen  41
# 5   2017  Stephen  41
# 6   2016  Stephen  44
# 7   2015  Stephen  43
# 8   2014  Stephen  42
# 9   2013  Stephen  43
# 10  2012  Stephen  42
# 11  2011  Stephen  45
# 12  2010  Stephen  44
# 13  2009  Stephen  46

# %% [markdown]
# ![n vs. year for Stephen Curry.png](data:image/png;base64,...)

# %% [markdown]
# Stephen's draft year in 2009 was at its highest probably because his performances had a lot of publicity. In his early NBA career, he was not as popular compared to the veterans like LeBron James. However, in 2015, he won his first MVP and championship followed by one of the most breakout seasons the NBA has seen. This can attribute to the rise in his name from 2014-2016. The drop off in his name could possibly be due those years were his peak performing seasons.

# %% [markdown]
# ## Kevin Garnett

# %% [markdown]
# ![1216163912.jpg](data:image/jpeg;base64,...)

# %%
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/1NlJHbc-EuMvn0U-31MFMF36QNk7NRc3WELM8N-dmvlE/edit?usp=sharing')
sheet = sp.worksheet('Sheet1')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0   year   name   n
# 1   2021  Kevin  45
# 2   2020  Kevin  44
# 3   2019  Kevin  44
# 4   2018  Kevin  48
# 5   2017  Kevin  47
# 6   2016  Kevin  47
# 7   2015  Kevin  46
# 8   2014  Kevin  47
# 9   2013  Kevin  47
# 10  2012  Kevin  49
# 11  2011  Kevin  49
# 12  2010  Kevin  49
# 13  2009  Kevin  50
# 14  2008  Kevin  49
# 15  2007  Kevin  48
# 16  2006  Kevin  52
# 17  2005  Kevin  50
# 18  2004  Kevin  54
# 19  2003  Kevin  52
# 20  2002  Kevin  53
# 21  2001  Kevin  51
# 22  2000  Kevin  52
# 23  1999  Kevin  51
# 24  1998  Kevin  52
# 25  1997  Kevin  53
# 26  1996  Kevin  53
# 27  1995  Kevin  54

# %% [markdown]
# ![n vs. year for Kevin Garnett.png](data:image/png;base64,...)

# %% [markdown]
# Kevin Garnett was one of the first players to be drafted in the NBA after high school, so his popularity already started at a relatively high level. In the early 2000s, he had breakout seasons where he was among one of the best forwards in the league. This saw his poplarity grow considerably as shown from the spikes in the figure.

# %% [markdown]
# ## Michael Jordan

# %% [markdown]
# ![michael-jordan-looks.jpg](data:image/jpeg;base64,...)

# %%
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/1zW0S-HaCsOa4sldWzmPcJflyk33TIho-Nkv7Cu1u_Iw/edit?usp=sharing')
sheet = sp.worksheet('Sheet1')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0   year     name   n
# 1   2021  Michael  51
# 2   2020  Michael  49
# 3   2019  Michael  51
# 4   2018  Michael  51
# 5   2017  Michael  51
# 6   2016  Michael  52
# 7   2015  Michael  53
# 8   2014  Michael  52
# 9   2013  Michael  51
# 10  2012  Michael  51
# 11  2011  Michael  51
# 12  2010  Michael  51
# 13  2009  Michael  52
# 14  2008  Michael  53
# 15  2007  Michael  52
# 16  2006  Michael  55
# 17  2005  Michael  52
# 18  2004  Michael  58
# 19  2003  Michael  57
# 20  2002  Michael  56
# 21  2001  Michael  55
# 22  2000  Michael  58
# 23  1999  Michael  60
# 24  1998  Michael  61
# 25  1997  Michael  61
# 26  1996  Michael  60
# 27  1995  Michael  59
# 28  1994  Michael  61
# 29  1993  Michael  64
# 30  1992  Michael  70
# 31  1991  Michael  64
# 32  1990  Michael  66
# 33  1989  Michael  74
# 34  1988  Michael  78
# 35  1987  Michael  82
# 36  1986  Michael  86
# 37  1985  Michael  82
# 38  1984  Michael  81

# %% [markdown]
# ![n vs. year for Michael Jordan.png](data:image/png;base64,...)

# %% [markdown]
# Michael was already a very popular name at the time he was drafted with the rise of famed music legend Michael Jackson. Nonetheless, despite the drops in popularity, we saw notable spikes in popularity that coincide with Jordan winning three straight in the early 1990s. This is possibly the only case we found where a confounding factor is in play for this trend.

# %% [markdown]
# ## Dwayne Wade

# %% [markdown]
# ![download.jfif](data:image/jpeg;base64,...)

# %%
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/18F-2zkV1fmPANdmKa0NaZ2wfQrTVt47B56wR4mhnnCM/edit?usp=sharing')
sheet = sp.worksheet('Sheet1')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0   year    name   n
# 1   2021  Dwayne  15
# 2   2020  Dwayne  13
# 3   2019  Dwayne  16
# 4   2018  Dwayne  20
# 5   2017  Dwayne  20
# 6   2016  Dwayne  16
# 7   2015  Dwayne  21
# 8   2014  Dwayne  20
# 9   2013  Dwayne  22
# 10  2012  Dwayne  23
# 11  2011  Dwayne  23
# 12  2010  Dwayne  24
# 13  2009  Dwayne  19
# 14  2008  Dwayne  21
# 15  2007  Dwayne  21
# 16  2006  Dwayne  22
# 17  2005  Dwayne  20
# 18  2004  Dwayne  18
# 19  2003  Dwayne  20

# %% [markdown]
# ![n vs. year for Dwayne Wade.png](data:image/png;base64,...)

# %% [markdown]
# Dwayne Wade's early career had strong popularity growth as he won the championship in his third season in 2006. With the arrival of LeBron James in the summer of 2010, the team overall grew in popularity substantially. This coincides with the how the figure above looks. The later years saw considerable drops as his career dwindled down and his performance decreased.

# %% [markdown]
# ## Results & Conclusion
#
# While we can't establish causation from this data, there are a number of distinct trends that emerged with each name in the sample. Larry Bird, for instance, won three champions in 1981, 1984 & 1986. While there wasn't a surge in the popularity of the name after this 5 year period, it saw a relatively high popularity in 1988. The name Larry remained consistently popular after this year. We also observed that, sometimes, a name's popularity surges years after the corresponding NBA championship. For example, Kobe won an NBA championship in 2010 (n = 38). In 2021, his name significantly rose in popularity (n = 44). It would be interesting to further investigate this trend by analyzing the average age of NBA championship viewers (e.g. the 2010 championship viewers might've had children in 2021). Lastly, Dwayne Wade won three NBA championships: 2006, 2012, & 2013. His name's popularity remained relatively stable throughout these years (n = 22, n = 23, n = 22, respectively); however, it declined in popularity in the years following, such as 2020 and 2021 (n = 13, n = 15). This suggests that a name might become less popular over time if an NBA player doesn't keep winning championships. Additionally, if the player does not perform on par with their breakout season, we could expect a drop off in popularity.
