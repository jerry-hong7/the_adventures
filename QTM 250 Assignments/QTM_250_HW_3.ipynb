# %% [markdown]
# <a href="https://colab.research.google.com/github/jerry-hong7/the_adventures/blob/main/QTM_250_HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Homework #3 QTM 250: Birth Rates**
# ### Group Members: Faiz Daredia, Conor Harty, Catherine Haus, Jerry Hong, and Lenora Upchurch

# %% [markdown]
# ## Introduction
#
# In recent years, the U.S. birth rate is the lowest it has been since the 1970s, and particularly low among Millennials and Generation Z. There are a number of reasons why this may be the case. Birth rates in the United States dropped during the pandemic, suggesting that economic instability may be a driving force behind this decline (Tavernise 2021). However, it’s important to consider long-term trends as well and U.S fertility rates have been falling since before the pandemic (Barroso 2021). An increasing number of  U.S. adults without children say they don’t expect to have them in the future, citing reasons including climate change. Indeed, 44% of those without children between the ages of 18 to 49 say it is “not too or not at all likely that they will have children someday,” a rise of 7% since 2018 (Brown 2021).
#
# With our generation changing the historical normative of family structures, we are interested to see how birth rates have changed over time in the United States. In other words, are people actually having children later on in life? And are there generational variances in birth rates? Our goal is to see how birth rates vary based on generation and age.
#
# <center>
# <img src="https://raw.githubusercontent.com/catherinehaus/QTM250-example/main/smiling-baby-swaddle-clipart-simple-cute-smile-baby-swaddle-in-blue-wrap-flat-illustration-happy-infant-baby-swaddling-cartoon-style-kids-baby-shower-newborn-and-nursery-decoration-concept-vector.jpg?raw=true" width="200">
# <img src="https://raw.githubusercontent.com/catherinehaus/QTM250-example/main/cartoon-american-flag-2018-23.png?raw=true" width="200">
# </center>

# %% [markdown]
# With our generation changing the historical normative of family structures due to increasing fears over climate change, we are interested to see how birth rates have changed over time in the United States. In other words, we are looking at yearly data to investigate whether people are having fewer children. Our goal is to see how birth rates vary based on generation and age. We assume that young people today are prioritizing future changes more, so young people today are having progressively less children.
#
# We found three datasets published by the CDC about birth rates. We used the following datasets to conduct our research:
#
#
# (1) **2016 Data**: https://github.com/catherinehaus/QTM250-example/blob/main/births_2016.csv?raw=true
#
# (2) **2017 Data**: https://github.com/catherinehaus/QTM250-example/blob/main/births_2017.csv?raw=true
#
# (3) **2018 Data**: https://github.com/catherinehaus/QTM250-example/blob/main/births_2018.csv?raw=true.

# %% [markdown]
# ## Code

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import each SQL result table
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/1d_Cxa_3L3JTVLwfDLmZXiRIQqHJ-Xrz8lxEeivnFtlE/edit#gid=835515680')
sheet = sp.worksheet('2016')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0          Year        County_of_Residence County_of_Residence_FIPS Births  \
# 1    2016-01-01         Bossier Parish, LA                    22015   1751
# 2    2016-01-01           Ector County, TX                    48135   2814
# 3    2016-01-01        Hamilton County, TN                    47065   4293
# 4    2016-01-01        Brazoria County, TX                    48039   4800
# 5    2016-01-01          Sumner County, TN                    47165   2053
# ..          ...                        ...                      ...    ...
# 622  2016-01-01        Rockland County, NY                    36087   5440
# 623  2016-01-01        Tompkins County, NY                    36109    787
# 624  2016-01-01       Hampshire County, MA                    25015   1009
# 625  2016-01-01  Unidentified Counties, NH                    33999   2878
# 626  2016-01-01        Humboldt County, CA                     6023   1482
#
# ...

# %%
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/14s19MUcqF3iKpTnY-BGUQPXyGrXtYbRe5MLIv1ymHlQ/edit#gid=1390216743')
sheet = sp.worksheet('2017')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0          Year          County_of_Residence County_of_Residence_FIPS Births  \
# 1    2017-01-01              Linn County, OR                    41043   1456
# 2    2017-01-01        Washington County, RI                    44009    852
# 3    2017-01-01        Montgomery County, AL                     1101   3172
# 4    2017-01-01  East Baton Rouge Parish, LA                    22033   5975
# 5    2017-01-01           Cameron County, TX                    48061   6276
# ..          ...                          ...                      ...    ...
# 622  2017-01-01          Onondaga County, NY                    36067   5052
# 623  2017-01-01        Livingston County, MI                    26093   1764
# 624  2017-01-01           Spokane County, WA                    53063   5895
# 625  2017-01-01            Oswego County, NY                    36075   1248
# 626  2017-01-01              King County, WA                    53033  25300
#
# ...

# %%
sp = gc.open_by_url('https://docs.google.com/spreadsheets/d/1ywSGT0QsQ75eKGS7bzuNAv9SzjvbXYB6tY1MbO7IWeY/edit#gid=1070385476')
sheet = sp.worksheet('2018')
data = sheet.get_all_values()
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df
# Out:
# 0          Year        County_of_Residence County_of_Residence_FIPS Births  \
# 1    2018-01-01         Calhoun County, AL                     1015   1265
# 2    2018-01-01           Tulsa County, OK                    40143   8933
# 3    2018-01-01         Carroll County, GA                    13045   1540
# 4    2018-01-01         Saginaw County, MI                    26145   2182
# 5    2018-01-01    Hillsborough County, FL                    12057  17126
# ..          ...                        ...                      ...    ...
# 622  2018-01-01       Snohomish County, WA                    53061   9763
# 623  2018-01-01          Skagit County, WA                    53057   1386
# 624  2018-01-01            Maui County, HI                    15009   1828
# 625  2018-01-01  Unidentified Counties, HI                    15999    749
# 626  2018-01-01         Chester County, PA                    42029   5370
#
# ...

# %% [markdown]
# ## Looker Studio
#
# - Looker Studio Link: https://lookerstudio.google.com/reporting/14393b35-a17d-48b0-849b-9e76c7789347

# %% [markdown]
# ## Analysis
#
# Overall, while there is a slight decrease in the birth rate from 2016 to 2018, there is not enough variability for our results to be significant. It would be helpful to look at the decline in birth over a longer time period such as 30 years, and continue to study it in the future to see how it changes.

# %% [markdown]
# ![Screenshot 2023-04-04 090030.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The figure above shows the ten counties with the highest number of births. Los Angeles has a significantly higher birth rate than any of the other counties studied. One observation worth noting is that the top three counties have the highest populations among all the counties in the data set. Thus, it is expected that they would have the highest number of births.
#
# ![Screen Shot 2023-04-04 at 9.25.13 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-04-04 223757.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Conclusion
#
# Limitations in the dataset prevent us from having conclusive results. Over the three years we examined, there is not enough data to determine whether an increase in climate change discourse has led to a decrease in bitrh rate. Additionally, more research must be done to determine impacts of confounding variables, such as political unrest, economic status, etc, on the birth rate in the United States.
#
# Although birth rates declined between 2016 to 2018, lack of data from previous years hinders the ability to form accurate extrapolations. As research continues to be conducted, we will be able to measure the impact of changing climate on generational birth rate fluctuations and look at birth rates over a longer time frame to understand if this trend continues.
